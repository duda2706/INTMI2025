# %% [markdown]
# <a href="https://colab.research.google.com/github/duda2706/INTMI2025/blob/main/ALP_MARIAEDUARDAROBERTO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Algoritmo e logica de programação

# %% [markdown]
# ##Variáveis e Operadores

# %%
x = 5     #isso é uma variável
print(x)
# Out:
# 5

# %% [markdown]
# ##Operadores
#
# adição +
#
# subtração -
#
# divisão /
#
# multiplicação *
#
# resto da divisão %
#
# divisão inteira //
#
# exponenciação **

# %%
numero1 = 10
numero2 = 5

print("A soma é igual a: ", numero1 + numero2)
print("A subtração é igual a: ", numero1 - numero2)
print("A divisão é igual a: ", numero1 / numero2)
print("A multiplicação é igual a: ", numero1 * numero2)
print("A resto é igual a: ", numero1 % numero2)
print("A divisão inteira é igual a: ", numero1 // numero2)
print("A exponenciação é igual a: ", numero1 ** numero2)
# Out:
# A soma é igual a:  15
# A subtração é igual a:  5
# A divisão é igual a:  2.0
# A multiplicação é igual a:  50
# A resto é igual a:  0
# A divisão inteira é igual a:  2
# A exponenciação é igual a:  100000

# %%
idade = input("Digite a sua idade: ")
# Out:
# Digite a sua idade: 16

# %% [markdown]
# ##Tipos de dados
#
# int - para números inteiros(1, 2, 3 )
#
# str - para palavras e texto(palavra)
#
# float - para números com vírgula(1.5 , 2.3)
#
# bool - para binários, verdadeiro ou falso(true, false)

# %%
altura = float(input("Digite sua altura: "))
peso = float(input("digite seu peso: "))

imc = peso / (altura * altura)
print("seu imc é: " , imc)
# Out:
# Digite sua altura: 1.65
# digite seu peso: 58
# seu imc é:  21.30394857667585

# %% [markdown]
# ##Estrutura Condicional
#
# if - se
#
# elif - senão se
#
# else - senão

# %%
nota = float(input("digite a sua nota: "))

if (nota >= 7):
  print("aprovado")
elif (nota >= 5):
  print("recuperação")
else:
  print("reprovado")
# Out:
# digite a sua nota: 10
# aprovado

# %% [markdown]
# 4 -
# Crie um algoritmo que leia a sua idade e dependendo da idade mostre as frases na tela:
#
# até 12 anos - Você é uma criança!
#
# 13 - 18     - Você é adolescente!
#
# 19 - 60     - Você é adulto!
#
# acima de 60 - Você é idoso!

# %%
idade = int(input("Digite sua idade: "))

if (idade <= 12):
  print(" Você é uma criança")
elif (idade <=18):
  print("Você é adolescente")
elif (idade <= 60):
  print("Você é adulto")
else:
  print("Você é idoso")
# Out:
# Digite sua idade: 16
# Você é adolescente

# %% [markdown]
# 5 - crie um algoritmo que receba 2 números e uma escolha que mostre o segundo menu:
#
# selecione o sinal:
#
# 1 - adição
#
# 2 - subtração
#
# 3 - multiplicação
#
# 4 - divisão
#
# caso não escolha um número válido apareça na tela: opção inválida!
#
# se escolher 1 some os 2 números e mostre o resultado.
#
# se escolher 2 subtraia os 2 números e mostre o resultado.
#
# e assim com as outras opções.
